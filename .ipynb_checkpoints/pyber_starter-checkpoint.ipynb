# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import colors as mcolors
import plotly.plotly as py
import cufflinks as cf
import plotly.graph_objs as go


# File to Load (Remember to change these)
city_data = pd.read_csv("city_data.csv")
ride_data = pd.read_csv("ride_data.csv")


# Read the City and Ride Data
#print(city_data.head())
#print(ride_data.head())

# Combine the data into a single dataset
df = pd.merge(ride_data, city_data, how="left", on=("city", "city"))
# Extract the year
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# Display the data table for preview
df.head()
# Out:
#                  city                date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire 2018-01-14 10:14:22  13.83  5739410935873             5
# 1  South Michelleport 2018-03-04 18:24:09  30.24  2343912425577            72
# 2  Port Samanthamouth 2018-02-24 04:29:00  33.44  2005065760003            57
# 3          Rodneyfort 2018-02-10 23:22:03  23.44  5149245426178            34
# 4          South Jack 2018-03-06 04:28:35  34.58  3908451377344            46
#
#     type  year
# 0  Urban  2018
# 1  Urban  2018
# 2  Urban  2018
# 3  Urban  2018
# 4  Urban  2018

# %%
# Create a datframe for metrics: Average Fare ($) Per City, # of Rides Per City, # of Drivers Per City, City Type
#df["type"].unique()
types_df = df.groupby(['city', 'type', 'driver_count']).agg({'fare':'mean','ride_id': 'count','year': 'count'}).rename(columns = {'fare': 'Avrg Fare', 'ride_id': 'Total Rides'}).reset_index()

types_df.head()
# Out:
#             city      type  driver_count  Avrg Fare  Total Rides  year
# 0    Amandaburgh     Urban            12  24.641667           18    18
# 1    Barajasview     Urban            26  25.332273           22    22
# 2  Barronchester  Suburban            11  36.422500           16    16
# 3    Bethanyland  Suburban            22  32.956111           18    18
# 4   Bradshawfurt     Rural             7  40.064000           10    10

# %%
# Create different dataframes for each type

urban = types_df.loc[types_df["type"] == "Urban"]
rural = types_df.loc[types_df["type"] == "Rural"]
suburban = types_df.loc[types_df["type"] == "Suburban"]
# Out:
#               city   type  driver_count  Avrg Fare  Total Rides  year
# 4     Bradshawfurt  Rural             7  40.064000           10    10
# 17       Garzaport  Rural             7  24.123333            3     3
# 20  Harringtonfort  Rural             4  33.470000            6     6
# 24     Jessicaport  Rural             1  36.013333            6     6
# 33      Lake Jamie  Rural             4  34.358333            6     6

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
from matplotlib.lines import Line2D

# Build the scatter plots for each city types
plt.scatter(urban["Total Rides"], urban["Avrg Fare"],
            s=urban["driver_count"] *10.5, alpha=.7,color = 'lightcoral', edgecolors='black');

plt.scatter(rural["Total Rides"], rural["Avrg Fare"],
            s=rural["driver_count"] *10.5, alpha=.7,color = 'gold', edgecolors='black');

plt.scatter(suburban["Total Rides"], suburban["Avrg Fare"],
            s=suburban["driver_count"] *10.5, alpha=.7,color = 'lightblue', edgecolors='black');

# Incorporate the other graph properties
title_font = {'fontname':'Arial', 'size':'16', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} 
axis_font = {'fontname':'Arial', 'size':'14'}

plt.xlabel('Total Number of Rides (per city)', **axis_font);
plt.ylabel('Average Fare ($)', **axis_font);
plt.title('Pyber Ride Sharing Data (2018)', **title_font);
plt.style.use('seaborn-whitegrid')

# Create a legend
line1 = Line2D(range(1), range(1), color="white", marker='o', markersize=10, markerfacecolor="lightcoral")
line2 = Line2D(range(1), range(1), color="white", marker='o',markersize=10, markerfacecolor="gold")
line3 = Line2D(range(1), range(1), color="white", marker='o',markersize=10, markerfacecolor="lightblue")
plt.legend((line1,line2,line3),('Urban','Rural', 'Suburban'),numpoints=1, loc=1, title='City Type', frameon=True);

# Incorporate a text label regarding circle size
plt.text(42, 40, 'Note:\nCircle size correlates with driver sizer per city', fontsize=14);


# Save Figure

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
types_df = df.groupby(['type']).agg({'fare': 'sum'}).reset_index()

# Build Pie Chart
labels = types_df['type']
colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0.1)

types_df.fare.plot(kind='pie', colors=colors, labels=labels, autopct="%1.1f%%", explode=explode, startangle=150, 
                   title="% of Total Fares by City Type", shadow=True);
plt.ylabel('')

# Save Figure
plt.savefig("City_Type_Fares.png")

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
types_df = df.groupby(['type']).agg({'ride_id': 'count'}).reset_index()

# Build Pie Chart
labels = types_df['type']
colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0.1)

types_df.ride_id.plot(kind='pie', colors=colors, labels=labels, autopct="%1.1f%%", explode=explode, startangle=150, 
                   title="% of Total Rides by City Type", shadow=True);
plt.ylabel('')

# Save Figure
plt.savefig("City_Type_Rides.png")

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
types_df = df.groupby(['type']).agg({'driver_count': 'sum'}).reset_index()

# Build Pie Charts
labels = types_df['type']
colors = ["gold", "lightblue", "lightcoral"]
explode = (0, 0, 0.1)

types_df.driver_count.plot(kind='pie', colors=colors, labels=labels, autopct="%1.1f%%", explode=explode, startangle=180, 
                   title="% of Total Drivers by City Type", shadow=True);
plt.ylabel('')

# Save Figure
plt.savefig("City_Type_Drivers.png")
